# %%
# %load_ext autoreload
# %autoreload
import gym
import matplotlib
# %matplotlib inline
from MonteCarlo import runMonteCarlo
from BlackJack import plotStateActionValueActions3D

# %% [markdown]
# ### Black Jack with Monte Carlo

# %%
env = gym.make("Blackjack-v0")

# %%
stateActionValues, visitCounts, policy = runMonteCarlo(env)
# Out:
# 100%|██████████| 100000/100000 [00:20<00:00, 4776.90it/s, meanReward=-.188]

# %%
plotStateActionValueActions3D(stateActionValues, usableAce=False)

# %% [markdown]
# ### Frozen Lake with Monte Carlo

# %%
env = gym.make("FrozenLake-v0")

# %%
env.action_space, env.observation_space
# Out:
# (Discrete(4), Discrete(16))

# %%
env.reset()
# Out:
# (12, 8, False)

# %%
# env.render()
env.step(0)
# Out:
# ((12, 8, False), 1.0, True, {})
