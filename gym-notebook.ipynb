# %%
# %load_ext autoreload
# %autoreload
import gym
import matplotlib
# %matplotlib inline
from MonteCarlo import runMonteCarlo
from EnvUtils import plotStateActionValues2D, plotStateActionValueActions3D

# %% [markdown]
# ### Black Jack with Monte Carlo

# %%
env = gym.make("Blackjack-v0")

# %%
stateActionValues, visitCounts, policy = runMonteCarlo(env, numEpisodes=100000)
# Out:
# 2021/03/17 10:25:43 WARNING mlflow.tracking.context.git_context: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Cmd('git') failed due to: exit code(1)
#   cmdline: git version
#   stderr: 'xcrun: error: active developer path ("/Applications/Xcode.app/Contents/Developer") does not exist
# Use `sudo xcode-select --switch path/to/Xcode.app` to specify the Xcode that you wish to use for command line developer tools, or use `xcode-select --install` to install the standalone command line developer tools.
# See `man xcode-select` for more details.'
# 100%|██████████| 100000/100000 [08:33<00:00, 194.56it/s, meanReward=-.18]

# %%
plotStateActionValueActions3D(stateActionValues, usableAce=False)

# %% [markdown]
# ### Frozen Lake with Monte Carlo

# %%
env = gym.make("FrozenLake8x8-v0")

# %%
stateActionValues, visitCounts, policy = runMonteCarlo(env, render=False, numEpisodes=1000000)
# Out:
# 100%|██████████| 1000000/1000000 [1:04:45<00:00, 257.37it/s, meanReward=0.00189]

# %%
plotStateActionValues2D(env, stateActionValues, shape=(8,8))
